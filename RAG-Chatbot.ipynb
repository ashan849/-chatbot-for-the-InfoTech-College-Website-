# %%
# Core dependencies
# !pip install langchain langchain-community langchain-ollama langchain-chroma sentence-transformers chromadb fastapi uvicorn streamlit pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\ashan\anaconda3\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-community in c:\users\ashan\anaconda3\lib\site-packages (0.3.29)
# Requirement already satisfied: langchain-ollama in c:\users\ashan\anaconda3\lib\site-packages (0.3.8)
# Requirement already satisfied: langchain-chroma in c:\users\ashan\anaconda3\lib\site-packages (0.2.6)
# Requirement already satisfied: sentence-transformers in c:\users\ashan\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: chromadb in c:\users\ashan\anaconda3\lib\site-packages (1.0.21)
# Requirement already satisfied: fastapi in c:\users\ashan\anaconda3\lib\site-packages (0.116.1)
# Requirement already satisfied: uvicorn in c:\users\ashan\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: streamlit in c:\users\ashan\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: pypdf in c:\users\ashan\anaconda3\lib\site-packages (6.0.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (0.4.28)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (2.11.9)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ashan\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: ollama<1.0.0,>=0.5.3 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-ollama) (0.5.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (4.56.1)
# Requirement already satisfied: tqdm in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (0.34.6)
# Requirement already satisfied: Pillow in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\ashan\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\ashan\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\ashan\anaconda3\lib\site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: click>=7.0 in c:\users\ashan\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\ashan\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\ashan\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ashan\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: jinja2 in c:\users\ashan\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: toolz in c:\users\ashan\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: pyproject_hooks in c:\users\ashan\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ashan\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\ashan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\ashan\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ashan\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: anyio in c:\users\ashan\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\ashan\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\ashan\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\ashan\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\ashan\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: filelock in c:\users\ashan\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ashan\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ashan\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ashan\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ashan\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ashan\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ashan\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ashan\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ashan\anaconda3\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\ashan\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ashan\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\ashan\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ashan\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\ashan\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\ashan\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\ashan\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\ashan\anaconda3\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashan\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ashan\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ashan\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ashan\anaconda3\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ashan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ashan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ashan\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ashan\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ashan\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ashan\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ashan\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ashan\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: networkx in c:\users\ashan\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: setuptools in c:\users\ashan\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ashan\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ashan\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ashan\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ashan\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\ashan\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ashan\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ashan\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\ashan\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ashan\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ashan\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\ashan\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ashan\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ashan\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ashan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ashan\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\ashan\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ashan\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ashan\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ashan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\ashan\anaconda3\lib\site-packages (6.0.0)

# %%
import tkinter
tkinter._test()

# %%
import tkinter as tk
from tkinter import scrolledtext
from langchain.vectorstores import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_ollama import ChatOllama
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader, PyPDFLoader
import os

# ---- SETTINGS ----
CHATBOT_NAME = "InfortechGPT"
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 50
TOP_K = 3
DOCS_DIR = "docs"

# ---- STEP 0: Initialize embedding model ----
embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# ---- STEP 0a: Load & split documents if updating vectorstore ----
if not os.path.exists("chroma_db") or len(os.listdir("chroma_db")) == 0:
    print(f"Creating new vectorstore with chunk_size={CHUNK_SIZE}...")
    loader = DirectoryLoader(DOCS_DIR, glob="*.pdf", loader_cls=PyPDFLoader)
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)
    docs_chunks = text_splitter.split_documents(documents)
    vectorstore = Chroma.from_documents(docs_chunks, embedding_model, persist_directory="chroma_db")
    vectorstore.persist()
    print("Vectorstore created and persisted.")
else:
    vectorstore = Chroma(persist_directory="chroma_db", embedding_function=embedding_model)

# ---- STEP 0b: Create retriever ----
retriever = vectorstore.as_retriever(search_kwargs={"k": TOP_K})

# ---- STEP 1: Initialize LLM ----
llm = ChatOllama(model="gemma3:1b")

# ---- STEP 2: Define prompt template ----
prompt = ChatPromptTemplate.from_template(
    f"{CHATBOT_NAME} is a helpful AI assistant.\nAnswer the following question based on the provided documents:\n{{context}}\n\nQuestion: {{input}}"
)

# ---- STEP 3: Create QA and RAG chains ----
qa_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, qa_chain)

# ---- GUI ----
def ask_question():
    user_query = input_box.get().strip()
    if not user_query:
        return
    input_box.delete(0, tk.END)
    result_text.insert(tk.END, f"{CHATBOT_NAME} is thinking...\n", "thinking")
    root.update()

    try:
        result = rag_chain.invoke({"input": user_query})
        answer = result.get("answer", "No answer found.")
        result_text.insert(tk.END, f"Q: {user_query}\n{CHATBOT_NAME}: {answer}\n\n", "answer")
        result_text.see(tk.END)
    except Exception as e:
        result_text.insert(tk.END, f"Error: {str(e)}\n\n", "error")

# ---- GUI Setup ----
root = tk.Tk()
root.title(CHATBOT_NAME)
root.geometry("750x550")
root.configure(bg="#1e1e2f")  # Dark background

# Title
tk.Label(root, text=CHATBOT_NAME, bg="#1e1e2f", fg="#f1f1f1", font=("Helvetica", 20, "bold")).pack(pady=10)

# Input box
input_frame = tk.Frame(root, bg="#1e1e2f")
input_frame.pack(pady=5)
tk.Label(input_frame, text="Enter your question:", bg="#1e1e2f", fg="#f1f1f1", font=("Helvetica", 12)).pack(side=tk.LEFT, padx=5)
input_box = tk.Entry(input_frame, width=60, font=("Helvetica", 12))
input_box.pack(side=tk.LEFT, padx=5)
tk.Button(input_frame, text="Ask", command=ask_question, bg="#4CAF50", fg="white", font=("Helvetica", 12, "bold"), activebackground="#45a049").pack(side=tk.LEFT, padx=5)

# Output box
tk.Label(root, text="Answer:", bg="#1e1e2f", fg="#f1f1f1", font=("Helvetica", 12)).pack(pady=5)
result_text = scrolledtext.ScrolledText(root, wrap=tk.WORD, width=90, height=25, font=("Helvetica", 12), bg="#2e2e3e", fg="#f1f1f1", insertbackground="white")
result_text.pack(pady=5)

# Text tags for color coding
result_text.tag_config("thinking", foreground="#FFD700", font=("Helvetica", 12, "italic"))
result_text.tag_config("answer", foreground="#00FF7F", font=("Helvetica", 12))
result_text.tag_config("error", foreground="#FF6347", font=("Helvetica", 12, "bold"))

root.mainloop()
